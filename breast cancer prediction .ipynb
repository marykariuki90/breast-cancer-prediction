# %% [markdown]
# # Breast cancer prediction

# %% [markdown]
# # problem statement
#  Binary Classification Prediction for type of Breast Cancer

# %% [markdown]
# # dataset
# The dataset used in this model was obtained from kaggle.with the following columns
# * ID number
#
# * Diagnosis (M = malignant, B = benign)
#
# * radius (mean of distances from center to points on the perimeter)
#
# * texture (standard deviation of gray-scale values)
#
# * perimeter
#
# * area
#
# * smoothness (local variation in radius lengths)
#
# * compactness (perimeter^2 / area - 1.0)
#
# * concavity (severity of concave portions of the contour)
#
# * concave points (number of concave portions of the contour)
#
# * symmetry
#
# * fractal dimension ("coastline approximation" - 1)

# %% [markdown]
# # Tools preparation
#
# pandas and numpy for data analysis and exploration
#
# seaborn and matplotlib fot data visualization
#
# RandomForestClassifier for building a model
#
# Accuracy_score,confusion_matrix,classification_report for metrics purposes

# %% [markdown]
# # loading the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# # loading the data

# %%
data=pd.read_csv("breast-cancer.csv")
data.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
data.tail(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 559  925291         B        11.51         23.93           74.52      403.5
# 560  925292         B        14.05         27.15           91.38      600.4
# 561  925311         B        11.20         29.37           70.67      386.0
# 562  925622         M        15.22         30.62          103.40      716.9
# 563  926125         M        20.92         25.09          143.00     1347.0
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# # data exploration and analysis

# %% [markdown]
# # checking the number of columns

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# # checking the total  number of rows and columns

# %%
data.shape
# Out:
# (569, 32)

# %% [markdown]
# # value_counts for target variable

# %%
data["diagnosis"].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# # checking for datatypes

# %%
data.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %% [markdown]
# # checking for null values

# %%
data.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %% [markdown]
# # checking for the duplicates

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # getting the summary of the data

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# # data visualization using seaborn,pandas and matplotlib

# %%
sns.set_style("ticks")
sns.pairplot(data,hue='diagnosis',diag_kind="kde",kind="scatter",palette="husl")
plt.show()

# %%
sns.countplot(x="diagnosis",data=data)
plt.title("shows the count on belin and maligant on diagnosis")
plt.show()

# %%
plot=plt.figure(figsize=(5,5))
sns.barplot(x='diagnosis',y='radius_mean',data=data)
plt.title('The distribution between the radius_mean and the diagnosis ')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x="diagnosis",y="concavity_worst",data=data)
plt.title('The distribution between the concavity_worst and the diagnosis ')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='diagnosis',y='fractal_dimension_worst',data=data)
plt.title('The distribution between the fractal_dimension_worst and the diagnosis ')
# Out:
# Text(0.5, 1.0, 'The distribution between the fractal_dimension_worst and the diagnosis ')

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='diagnosis',y='radius_se',data=data)
plt.title('The distribution between the radius_se and the diagnosis ')
# Out:
# Text(0.5, 1.0, 'The distribution between the radius_se and the diagnosis ')

# %% [markdown]
# # correlation

# %%
data.corr()
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(),annot=True)
plt.title("correlation between the features")
# Out:
# Text(0.5, 1.0, 'correlation between the features')

# %% [markdown]
# # data preprocessing

# %% [markdown]
# # label binarization
# am changing the label from categorical to numerical so that the model can be efficient

# %%
y=data['diagnosis'].apply(lambda y_value:0 if y_value == "B" else 1)

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %% [markdown]
# # Data splitting

# %%
x=data.drop(['id','diagnosis'],axis=1).values

# %%
y=data['diagnosis'].values

# %% [markdown]
# # getting the shape of x and y

# %%
x.shape
# Out:
# (569, 30)

# %%
y.shape
# Out:
# (569,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %% [markdown]
# # modelling using RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # determining the accuracy

# %%
pred=model.predict(x_test)
test=accuracy_score(pred,y_test)
test
# Out:
# 0.9385964912280702

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[65,  4],
#        [ 3, 42]], dtype=int64)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.96      0.94      0.95        69
#            M       0.91      0.93      0.92        45
#
#     accuracy                           0.94       114
#    macro avg       0.93      0.94      0.94       114
# weighted avg       0.94      0.94      0.94       114
